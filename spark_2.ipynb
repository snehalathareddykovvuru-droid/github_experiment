# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Data Frame').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://03c45ffee99b:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Data Frame</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#to read the data set
df=spark.read.option('header','true').csv('/content/test1.csv',inferSchema=True)
# inferSchema=true,if it shows the false as like string then it gives the correct data type

# %%
# to check the schema i.e to check the data type
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
type(df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df=spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
# selecting single column
df.select('name','age','experience').show()# to get more than one column we can also use list form
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# |     Ben| 31|        10|
# |Srikanth| 30|         8|
# |   Sunny| 29|         4|
# |    Paul| 24|         3|
# |  Harish| 21|         1|
# |   Shiva| 23|         2|
# +--------+---+----------+

# %%
df.filter(df['name'] =='ben').show()
# Out:
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# +----+---+----------+------+
# +----+---+----------+------+

# %%
df.filter(df['age']=='23').show()
# Out:
# +-----+---+----------+------+
# | Name|age|Experience|Salary|
# +-----+---+----------+------+
# |Shiva| 23|         2| 18000|
# +-----+---+----------+------+

# %%
#to check the data types
df.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
# it shows through ascii values through the letters
df.describe().show() # it shows the statical summary
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
ord('A')# to calculate the ascii values we can also use inthe python code
# Out:
# 65

# %%
# it is used to add the column
df=df.withColumn('Experience After 2 years',df['Experience']+2)

# %%
# it is used to drop the column
df=df.drop('Experience After 2 years')

# %%
# rename the column
df=df.withColumnRenamed('Name','New_Name').show()
# Out:
# +--------+---+----------+------+
# |New_Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+
