# %%
t=6,8,9
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
l=[9,0,67,0,8,8]
set(l)# how to remove the duplicate values
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',7888888,4556,9}
s
# Out:
# {4556, 6, 7888888, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',7888888,4556,9,(8,88)}
s
# Out:
# {(8, 88), 4556, 6, 7888888, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',7888888,4556,9,{8,88}}
s# list and the set are not exute
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15640/1759088891.py in <module>
# ----> 1 s={89,90,6,'p',7888888,4556,9,{8,88}}
#       2 s
#
# TypeError: unhashable type: 'set'

# %%
s=[89,90,6,'p',7888888,4556,9,(8,88)]
s[0]=9
s
# Out:
# [9, 90, 6, 'p', 7888888, 4556, 9, (8, 88)]

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,6,2])
s
# Out:
# {0, 2, 6, 7, 9}

# %%
s={9,9,0}
s.add([7,6,2])
s# we cont add many elements
#through list we can update only like individual elements
#if use the add for multiple elements we need to use tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15640/4026052340.py in <module>
#       1 s={9,9,0}
# ----> 2 s.add([7,6,2])
#       3 s
#
# TypeError: unhashable type: 'list'

# %%
s={9,9,0}
s.add((9,6,20))
s
# Out:
# {(9, 6, 20), 0, 9}

# %%
# i want to delete values
s={5,8,9}
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(8)
s # by discard method if we need to remove the unnown no it doesnt show the any error
# if the element is not there remove will give the error
# Out:
# {5, 9}

# %%
s={5,8,9}
s.pop()
s
# Out:
# {5, 9}
