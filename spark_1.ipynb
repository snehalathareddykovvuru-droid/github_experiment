# %% [markdown]
# <a href="https://colab.research.google.com/github/snehalathareddykovvuru-droid/github_experiment/blob/master/spark_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark
import pandas as pd

# %%
# i want to read the data frame through pandas
df=pd.read_csv('/content/test1.csv')
df.head() #default it gives first 5 data
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000

# %%
df.shape # how many are there the column and rows
# Out:
# (6, 4)

# %%
df.info() # it gives the column name and null values there r not and the data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   age         6 non-null      int64
#  2   Experience  6 non-null      int64
#  3   Salary      6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes

# %%
type(pd.read_csv('/content/test1.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Demo').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://75a719a460fa:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Demo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.csv('/content/test1.csv')

# %%
df
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string]

# %%
df.show()# to find the dimentional of the data
# it shows the index data as c0,c1,c2,c3
# Out:
# +--------+---+----------+------+
# |     _c0|_c1|       _c2|   _c3|
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df=spark.read.option('header','true').csv('test1.csv') # it is used to remove the index data

# %%
df
# Out:
# DataFrame[Name: string, age: string, Experience: string, Salary: string]

# %%
df.show(3)
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# +--------+---+----------+------+
# only showing top 3 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df.head()
# Out:
# Row(Name='Ben', age='31', Experience='10', Salary='30000')
